# %%
import tensorflow as tf
import pandas as pd

# %%
# /content/drive/MyDrive/Colab Notebooks/Santander Kaggle Challenge/Data Raw/sample_submission.csv

# /content/drive/MyDrive/Colab Notebooks/Santander Kaggle Challenge/Data Raw/test.csv

# %%
submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Santander Kaggle Challenge/Data Raw/sample_submission.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Santander Kaggle Challenge/Data Preprocessed/preprocessed_test_data.csv') #IMPORTANT not to use raw data but the expanded csv after Feature engineering
train_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Santander Kaggle Challenge/Data Raw/train.csv')

# %%
print(test_data.shape)
print(train_data.shape)
print(submission.shape)
# Out:
# (200000, 400)
# (200000, 202)
# (200000, 2)

# %%
submission.head()
# Out:
#   ID_code  target
# 0  test_0       0
# 1  test_1       0
# 2  test_2       0
# 3  test_3       0
# 4  test_4       0

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Santander Kaggle Challenge/Models/model_V1.h5')

# %%
print(test_data.columns)
# Out:
# Index(['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6', 'var_7',
#        'var_8', 'var_9',
#        ...
#        'var_190_unique', 'var_191_unique', 'var_192_unique', 'var_193_unique',
#        'var_194_unique', 'var_195_unique', 'var_196_unique', 'var_197_unique',
#        'var_198_unique', 'var_199_unique'],
#       dtype='object', length=400)

# %%
#test_data = test_data.drop(['ID_code'], axis=1)

# %%
target_predictions = model.predict(test_data)
# Out:
# 6250/6250 [==============================] - 9s 1ms/step

# %%
submission['target'] = target_predictions

# %%
submission.to_csv('/content/drive/MyDrive/Colab Notebooks/Santander Kaggle Challenge/Submissions/final_submission_V1.csv', index=False)
